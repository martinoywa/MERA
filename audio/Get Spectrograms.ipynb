# %%
import os

# %%
path = "spectrograms/"

# %%
for path_dir, x, files in os.walk(path): pass

# %%
# get all downloaded spectrogram ids
ids_to_drop = [id[:-4] for id in files]
print(len(ids_to_drop))
# Out:
# 187

# %%
from audio_service import create_spectrogram

import pandas as pd

# %%
data = pd.read_csv("../data/train.csv")
data.head()
# Out:
#    dzr_sng_id          MSD_sng_id        MSD_track_id   valence   arousal  \
# 0      213754  SORORTY12A67ADD67E  TRJIEJX12903CF2202 -0.682725  0.316758
# 1      216752  SOVJXGK12A8AE4760C  TRLBHVY128F4242C31 -1.400403  1.538229
# 2      254391  SOUTMGD12A8AE47448  TRCXLKK128F42366BF  0.815393  0.662457
# 3      266313  SOTITAA12A6D4F8DA4  TRPMWQM128F932C0C8  1.257460  1.086515
# 4      283306  SOCSRIF12AB018E4FC  TRABHPA12903CEC222  0.373325 -0.923151
#
#          artist_name             track_name  \
# 0  Dark Tranquillity   Insanity's Crescendo
# 1   Anorexia Nervosa  Stabat mater dolorosa
# 2    Uniting Nations           Out Of Touch
# 3        The Walkmen       Brandy alexander
# 4     Duke Ellington                Caravan
#
#                                               Lyrics
# 0  Gently hold our hands\r\nGently hold our heads...
# 1  We are the Sun\r\nWe are the dead stars\r\nWe ...
# 2  You're out of touch\r\nI'm out of time\r\nBut ...
# 3  You finally close the door\r\nYou've left open...
# 4  随分先に行ってしまった 光の下のキャラバン\r\nトンネルに残響 塞いだ耳 自分嫌いな自分が...

# %%
data.shape
# Out:
# (10515, 8)

# %%
# ignore all rows with already downloaded spectrograms
data = data[~data["dzr_sng_id"].isin(ids_to_drop)]
data.head()
# Out:
#      dzr_sng_id          MSD_sng_id        MSD_track_id   valence   arousal  \
# 187      562488  SOEDECX12A5891DB18  TRCYQFE128F42ADA40  0.815393  0.662457
# 188      562489  SOKIBSD12AB017B1B4  TRHEBDB128F92E9FC0  0.218693  1.403022
# 189      562493  SOKOYGV12A58A8039A  TRYTKQE128F42ADA50 -0.959700 -0.132651
# 190      562494  SONLRZG12A8C14074F  TRNHCIP128F42ADA54 -1.700572  1.842444
# 191      562496  SOEQTOA12A8C13DB60  TRUMPOM128F42ADA5C  0.815393  0.662457
#
#     artist_name               track_name  \
# 187     Shakira              Animal City
# 188     Shakira             Don't Bother
# 189     Shakira             Your Embrace
# 190     Shakira  Costume Makes the Clown
# 191     Shakira                    Timor
#
#                                                 Lyrics
# 187  Why do all my friends now want to be your love...
# 188  She's got the kind of look that defies gravity...
# 189  Tell me, what's the use of a 24-inch waist\r\n...
# 190  Told you I felt lucky with my humble breasts\r...
# 191  Timor, Timor\r\nYale, Yale\r\nEast Timor, Timo...

# %%
data.shape
# Out:
# (10328, 8)

# %%
ids = data["dzr_sng_id"]
artists = data["artist_name"]
tracks = data["track_name"]

# %%
for i in range(len(ids)):
    create_spectrogram(ids.iloc[i], artists.iloc[i], tracks.iloc[i])
# Out:
# [youtube] 00CTd0DpySs: Downloading webpage
# [download] Destination: Shakira - Animal City (Lyrics)-00CTd0DpySs.webm
# [download] 100% of 1.18MiB in 00:04
# [ffmpeg] Destination: Shakira - Animal City (Lyrics)-00CTd0DpySs.mp3
# Deleting original file Shakira - Animal City (Lyrics)-00CTd0DpySs.webm (pass -k to keep)
# Shakira - Animal City (Lyrics)-00CTd0DpySs.mp3
# C:\Users\marti\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7558: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
# [youtube] MjRRQdnOR-A: Downloading webpage
# [download] Destination: Shakira - Don't Bother-MjRRQdnOR-A.webm
# [download] 100% of 1.61MiB in 00:02
# [ffmpeg] Destination: Shakira - Don't Bother-MjRRQdnOR-A.mp3
# Deleting original file Shakira - Don't Bother-MjRRQdnOR-A.webm (pass -k to keep)
# Shakira - Don't Bother-MjRRQdnOR-A.mp3
# [youtube] h-gBqpe1lDQ: Downloading webpage
# [download] Destination: 09 Shakira - Your Embrace [Lyrics]-h-gBqpe1lDQ.webm
# [download] 100% of 1.33MiB in 00:05
# [ffmpeg] Destination: 09 Shakira - Your Embrace [Lyrics]-h-gBqpe1lDQ.mp3
# Deleting original file 09 Shakira - Your Embrace [Lyrics]-h-gBqpe1lDQ.webm (pass -k to keep)
# 09 Shakira - Your Embrace [Lyrics]-h-gBqpe1lDQ.mp3
# [youtube] rcVstcGm-vY: Downloading webpage
# [download] Destination: 10 Shakira - Costume Makes The Clown [Lyrics]-rcVstcGm-vY.webm
# [download] 100% of 1.18MiB in 00:05
# [ffmpeg] Destination: 10 Shakira - Costume Makes The Clown [Lyrics]-rcVstcGm-vY.mp3
# Deleting original file 10 Shakira - Costume Makes The Clown [Lyrics]-rcVstcGm-vY.webm (pass -k to keep)
# 10 Shakira - Costume Makes The Clown [Lyrics]-rcVstcGm-vY.mp3
# [youtube] 7MnGx3bvaeA: Downloading webpage
# [download] Destination: 12 Shakira - Timor [Lyrics]-7MnGx3bvaeA.webm
# [download] 100% of 1.31MiB in 00:04
# [ffmpeg] Destination: 12 Shakira - Timor [Lyrics]-7MnGx3bvaeA.mp3
# Deleting original file 12 Shakira - Timor [Lyrics]-7MnGx3bvaeA.webm (pass -k to keep)
# 12 Shakira - Timor [Lyrics]-7MnGx3bvaeA.mp3
# [youtube] d6EvmvYzvj0: Downloading webpage
# [download] Destination: Matisyahu -- Lord Raise Me Up-d6EvmvYzvj0.webm
# [download] 100% of 1.44MiB in 00:04
# [ffmpeg] Destination: Matisyahu -- Lord Raise Me Up-d6EvmvYzvj0.mp3
# Deleting original file Matisyahu -- Lord Raise Me Up-d6EvmvYzvj0.webm (pass -k to keep)
# Matisyahu -- Lord Raise Me Up-d6EvmvYzvj0.mp3
# [youtube] irxZsKBTXCQ: Downloading webpage
# [download] Destination: Jessica Simpson - A Public Affair (Official Video)-irxZsKBTXCQ.webm
# [download] 100% of 1.48MiB in 00:05
# [ffmpeg] Destination: Jessica Simpson - A Public Affair (Official Video)-irxZsKBTXCQ.mp3
# Deleting original file Jessica Simpson - A Public Affair (Official Video)-irxZsKBTXCQ.webm (pass -k to keep)
# Jessica Simpson - A Public Affair (Official Video)-irxZsKBTXCQ.mp3
# [youtube] KCIrE445BXw: Downloading webpage
# [download] Destination: Ben Folds - In Between Days-KCIrE445BXw.webm
# [download] 100% of 1.00MiB in 00:05
# [ffmpeg] Destination: Ben Folds - In Between Days-KCIrE445BXw.mp3
# Deleting original file Ben Folds - In Between Days-KCIrE445BXw.webm (pass -k to keep)
# Ben Folds - In Between Days-KCIrE445BXw.mp3
# [youtube] CXRGnFD63Dg: Downloading webpage
# [download] Destination: Ben Folds - All U Can Eat-CXRGnFD63Dg.webm
# [download] 100% of 1.32MiB in 00:09
# [ffmpeg] Destination: Ben Folds - All U Can Eat-CXRGnFD63Dg.mp3
# Deleting original file Ben Folds - All U Can Eat-CXRGnFD63Dg.webm (pass -k to keep)
# Ben Folds - All U Can Eat-CXRGnFD63Dg.mp3
# [youtube] ReW_7xbPm8o: Downloading webpage
# [download] Destination: Ben Folds - Songs of Love-ReW_7xbPm8o.webm
# [download] 100% of 1.46MiB in 00:05
# [ffmpeg] Destination: Ben Folds - Songs of Love-ReW_7xbPm8o.mp3
# Deleting original file Ben Folds - Songs of Love-ReW_7xbPm8o.webm (pass -k to keep)
# Ben Folds - Songs of Love-ReW_7xbPm8o.mp3
# [youtube] yF_doTsG4t0: Downloading webpage
# [download] Destination: Ben Folds - Learn to Live with What You Are (Video)-yF_doTsG4t0.webm
# [download] 100% of 1.75MiB in 00:08
# [ffmpeg] Destination: Ben Folds - Learn to Live with What You Are (Video)-yF_doTsG4t0.mp3
# Deleting original file Ben Folds - Learn to Live with What You Are (Video)-yF_doTsG4t0.webm (pass -k to keep)
# Ben Folds - Learn to Live with What You Are (Video)-yF_doTsG4t0.mp3
# [youtube] FXZoBvygp4U: Downloading webpage
# [download] Destination: Gloria Estefan - Live For Loving You-FXZoBvygp4U.webm
# [download] 100% of 1.73MiB in 00:06
# [ffmpeg] Destination: Gloria Estefan - Live For Loving You-FXZoBvygp4U.mp3
# Deleting original file Gloria Estefan - Live For Loving You-FXZoBvygp4U.webm (pass -k to keep)
# Gloria Estefan - Live For Loving You-FXZoBvygp4U.mp3
# [youtube] dluHzQhLcME: Downloading webpage
# [download] Destination: Sananda Maitreya - Sign Your Name-dluHzQhLcME.webm
# [download] 100% of 1.81MiB in 00:05
# [ffmpeg] Destination: Sananda Maitreya - Sign Your Name-dluHzQhLcME.mp3
# Deleting original file Sananda Maitreya - Sign Your Name-dluHzQhLcME.webm (pass -k to keep)
# Sananda Maitreya - Sign Your Name-dluHzQhLcME.mp3
# [youtube] ynIHsHYaig0: Downloading webpage
# [download] Destination: Sananda Maitreya - Wishing Well (Video)-ynIHsHYaig0.webm
# [download] 100% of 1.23MiB in 00:06
# [ffmpeg] Destination: Sananda Maitreya - Wishing Well (Video)-ynIHsHYaig0.mp3
# Deleting original file Sananda Maitreya - Wishing Well (Video)-ynIHsHYaig0.webm (pass -k to keep)
# Sananda Maitreya - Wishing Well (Video)-ynIHsHYaig0.mp3
# [youtube] D-NvQ6VJYtE: Downloading webpage
# [download] Destination: Jamiroquai - Cosmic Girl (Official Video)-D-NvQ6VJYtE.webm
# [download] 100% of 1.49MiB in 00:05
# [ffmpeg] Destination: Jamiroquai - Cosmic Girl (Official Video)-D-NvQ6VJYtE.mp3
# Deleting original file Jamiroquai - Cosmic Girl (Official Video)-D-NvQ6VJYtE.webm (pass -k to keep)
# Jamiroquai - Cosmic Girl (Official Video)-D-NvQ6VJYtE.mp3
# [youtube] 7Hiy-E5w9eE: Downloading webpage
# [download] Destination: Jamiroquai - Love Foolosophy [Official Video]-7Hiy-E5w9eE.webm
# [download] 100% of 1.45MiB in 00:04
# [ffmpeg] Destination: Jamiroquai - Love Foolosophy [Official Video]-7Hiy-E5w9eE.mp3
# Deleting original file Jamiroquai - Love Foolosophy [Official Video]-7Hiy-E5w9eE.webm (pass -k to keep)
# Jamiroquai - Love Foolosophy [Official Video]-7Hiy-E5w9eE.mp3
# [youtube] iuz_XTAzAts: Downloading webpage
# [download] Destination: Cypress Hill - Till Death Do Us Part-iuz_XTAzAts.m4a
# [download] 100% of 3.56MiB in 00:05
# [ffmpeg] Destination: Cypress Hill - Till Death Do Us Part-iuz_XTAzAts.mp3
# Deleting original file Cypress Hill - Till Death Do Us Part-iuz_XTAzAts.m4a (pass -k to keep)
# Cypress Hill - Till Death Do Us Part-iuz_XTAzAts.mp3
# [youtube] _Vx2_khNdT4: Downloading webpage
# [download] Destination: tony braxton i love me some him-_Vx2_khNdT4.webm
# [download] 100% of 1.90MiB in 00:03
# [ffmpeg] Destination: tony braxton i love me some him-_Vx2_khNdT4.mp3
# Deleting original file tony braxton i love me some him-_Vx2_khNdT4.webm (pass -k to keep)
# tony braxton i love me some him-_Vx2_khNdT4.mp3
# [youtube] wpaR3wzTlvo: Downloading webpage
# [download] Destination: Toni Braxton - Just Be A Man About It (Official Music Video)-wpaR3wzTlvo.webm
# [download] 100% of 1.85MiB in 00:03
# [ffmpeg] Destination: Toni Braxton - Just Be A Man About It (Official Music Video)-wpaR3wzTlvo.mp3
# Deleting original file Toni Braxton - Just Be A Man About It (Official Music Video)-wpaR3wzTlvo.webm (pass -k to keep)
# Toni Braxton - Just Be A Man About It (Official Music Video)-wpaR3wzTlvo.mp3
# [youtube] p2Rch6WvPJE: Downloading webpage
# [download] Destination: Toni Braxton - Un-Break My Heart (Official HD Video)-p2Rch6WvPJE.webm
# [download] 100% of 1.72MiB in 00:02
# [ffmpeg] Destination: Toni Braxton - Un-Break My Heart (Official HD Video)-p2Rch6WvPJE.mp3
# Deleting original file Toni Braxton - Un-Break My Heart (Official HD Video)-p2Rch6WvPJE.webm (pass -k to keep)
# Toni Braxton - Un-Break My Heart (Official HD Video)-p2Rch6WvPJE.mp3
# [youtube] itjZzYplQSI: Downloading webpage
# [download] Destination: Toni Braxton - Seven Whole Days (Official Music Video)-itjZzYplQSI.webm
# [download] 100% of 1.60MiB in 00:31
# [ffmpeg] Destination: Toni Braxton - Seven Whole Days (Official Music Video)-itjZzYplQSI.mp3
# Deleting original file Toni Braxton - Seven Whole Days (Official Music Video)-itjZzYplQSI.webm (pass -k to keep)
# Toni Braxton - Seven Whole Days (Official Music Video)-itjZzYplQSI.mp3
# [youtube] n1T9G_d8RJ4: Downloading webpage
# [download] Destination: Blue Oyster Cult - Death Valley Nights-n1T9G_d8RJ4.webm
# [download] 100% of 1.56MiB in 00:04
# [ffmpeg] Destination: Blue Oyster Cult - Death Valley Nights-n1T9G_d8RJ4.mp3
# Deleting original file Blue Oyster Cult - Death Valley Nights-n1T9G_d8RJ4.webm (pass -k to keep)
# Blue Oyster Cult - Death Valley Nights-n1T9G_d8RJ4.mp3
# [youtube] ognBcHjlcJo: Downloading webpage
# [download] Destination: Blue Oyster Cult - I Love The Night-ognBcHjlcJo.webm
# [download] 100% of 1.75MiB in 00:04
# [ffmpeg] Destination: Blue Oyster Cult - I Love The Night-ognBcHjlcJo.mp3
# Deleting original file Blue Oyster Cult - I Love The Night-ognBcHjlcJo.webm (pass -k to keep)
# Blue Oyster Cult - I Love The Night-ognBcHjlcJo.mp3
# [youtube] FVhDdY7lOc8: Downloading webpage
# [download] Destination: Ginuwine - When Doves Cry-FVhDdY7lOc8.webm
# [download] 100% of 1.45MiB in 00:06
# [ffmpeg] Destination: Ginuwine - When Doves Cry-FVhDdY7lOc8.mp3
# Deleting original file Ginuwine - When Doves Cry-FVhDdY7lOc8.webm (pass -k to keep)
# Ginuwine - When Doves Cry-FVhDdY7lOc8.mp3
# [youtube] U_90XNCBatY: Downloading webpage
# [download] Destination: Ginuwine - Differences (Official Video)-U_90XNCBatY.webm
# [download] 100% of 1.59MiB in 00:02
# [ffmpeg] Destination: Ginuwine - Differences (Official Video)-U_90XNCBatY.mp3
# Deleting original file Ginuwine - Differences (Official Video)-U_90XNCBatY.webm (pass -k to keep)
# Ginuwine - Differences (Official Video)-U_90XNCBatY.mp3
# [youtube] rjKqlXLz7hE: Downloading webpage
# [download] Destination: Kristin Chenoweth - 'Poor, Wayfaring Stranger' (A&E's Breakfast with the Arts 17-April-2005)-rjKqlXLz7hE.webm
# [download] 100% of 1.05MiB in 00:04
# [ffmpeg] Destination: Kristin Chenoweth - 'Poor, Wayfaring Stranger' (A&E's Breakfast with the Arts 17-April-2005)-rjKqlXLz7hE.mp3
# Deleting original file Kristin Chenoweth - 'Poor, Wayfaring Stranger' (A&E's Breakfast with the Arts 17-April-2005)-rjKqlXLz7hE.webm (pass -k to keep)
# Kristin Chenoweth - 'Poor, Wayfaring Stranger' (A&E's Breakfast with the Arts 17-April-2005)-rjKqlXLz7hE.mp3
# [youtube] 0vipJ_DATW8: Downloading webpage
# [download] Destination: Brandi Carlile 'Follow' At - Guitar Center-0vipJ_DATW8.webm
# [download] 100% of 1.64MiB in 00:05
# [ffmpeg] Destination: Brandi Carlile 'Follow' At - Guitar Center-0vipJ_DATW8.mp3
# Deleting original file Brandi Carlile 'Follow' At - Guitar Center-0vipJ_DATW8.webm (pass -k to keep)
# Brandi Carlile 'Follow' At - Guitar Center-0vipJ_DATW8.mp3
# [youtube] cKzrW-Na958: Downloading webpage
# [download] Destination: Brandi Carlile - What Can I Say-cKzrW-Na958.webm
# [download] 100% of 1.11MiB in 00:03
# [ffmpeg] Destination: Brandi Carlile - What Can I Say-cKzrW-Na958.mp3
# Deleting original file Brandi Carlile - What Can I Say-cKzrW-Na958.webm (pass -k to keep)
# Brandi Carlile - What Can I Say-cKzrW-Na958.mp3
# [youtube] y6IrcLkh9Hc: Downloading webpage
# [download] Destination: Brandi Carlile - Someday Never Comes-y6IrcLkh9Hc.webm
# [download] 100% of 1.08MiB in 00:04
# [ffmpeg] Destination: Brandi Carlile - Someday Never Comes-y6IrcLkh9Hc.mp3
# Deleting original file Brandi Carlile - Someday Never Comes-y6IrcLkh9Hc.webm (pass -k to keep)
# Brandi Carlile - Someday Never Comes-y6IrcLkh9Hc.mp3
# [youtube] jtv7uyNG37M: Downloading webpage
# [download] Destination: Brandi Carlile - In My Own Eyes-jtv7uyNG37M.webm
# [download] 100% of 1.32MiB in 00:04
# [ffmpeg] Destination: Brandi Carlile - In My Own Eyes-jtv7uyNG37M.mp3
# Deleting original file Brandi Carlile - In My Own Eyes-jtv7uyNG37M.webm (pass -k to keep)
# Brandi Carlile - In My Own Eyes-jtv7uyNG37M.mp3
# [youtube] M1baDSAe0dA: Downloading webpage
# [download] Destination: Brandi Carlile - Tragedy - lyrics-M1baDSAe0dA.webm
# [download] 100% of 1.40MiB in 00:04
# [ffmpeg] Destination: Brandi Carlile - Tragedy - lyrics-M1baDSAe0dA.mp3
# Deleting original file Brandi Carlile - Tragedy - lyrics-M1baDSAe0dA.webm (pass -k to keep)
# Brandi Carlile - Tragedy - lyrics-M1baDSAe0dA.mp3
# [youtube] oC6iyw8u_P0: Downloading webpage
# [download] Destination: Brandi Carlile, Fall Apart Again-oC6iyw8u_P0.webm
# [download] 100% of 1.71MiB in 00:05
# [ffmpeg] Destination: Brandi Carlile, Fall Apart Again-oC6iyw8u_P0.mp3
# Deleting original file Brandi Carlile, Fall Apart Again-oC6iyw8u_P0.webm (pass -k to keep)
# Brandi Carlile, Fall Apart Again-oC6iyw8u_P0.mp3
# [youtube] Tv-5snutHG0: Downloading webpage
# [download] Destination: Switchfoot - Stars-Tv-5snutHG0.webm
# [download] 100% of 1.34MiB in 00:05
# [ffmpeg] Destination: Switchfoot - Stars-Tv-5snutHG0.mp3
# Deleting original file Switchfoot - Stars-Tv-5snutHG0.webm (pass -k to keep)
# Switchfoot - Stars-Tv-5snutHG0.mp3
# [youtube] ido_AIZeLw0: Downloading webpage
# [download] Destination: Just Want You To Know - Backstreet Boys-ido_AIZeLw0.webm
# [download] 100% of 1.62MiB in 00:06
# [ffmpeg] Destination: Just Want You To Know - Backstreet Boys-ido_AIZeLw0.mp3
# Deleting original file Just Want You To Know - Backstreet Boys-ido_AIZeLw0.webm (pass -k to keep)
# Just Want You To Know - Backstreet Boys-ido_AIZeLw0.mp3
# [youtube] aO7mxofsQXQ: Downloading webpage
# [download] Destination: Oasis - Eyeball Tickler-aO7mxofsQXQ.webm
# [download] 100% of 959.07KiB in 00:05
# [ffmpeg] Destination: Oasis - Eyeball Tickler-aO7mxofsQXQ.mp3
# Deleting original file Oasis - Eyeball Tickler-aO7mxofsQXQ.webm (pass -k to keep)
# Oasis - Eyeball Tickler-aO7mxofsQXQ.mp3
# [youtube] tC6PFzLncok: Downloading webpage
# [download] Destination: Eliane Elias - Time Alone - Dreamer (2004).wmv-tC6PFzLncok.webm
# [download] 100% of 2.62MiB in 00:06
# [ffmpeg] Destination: Eliane Elias - Time Alone - Dreamer (2004).wmv-tC6PFzLncok.mp3
# Deleting original file Eliane Elias - Time Alone - Dreamer (2004).wmv-tC6PFzLncok.webm (pass -k to keep)
# Eliane Elias - Time Alone - Dreamer (2004).wmv-tC6PFzLncok.mp3
# [youtube] KhARfCRjLGs: Downloading webpage
# [download] Destination: Emma Roberts - Punch Rocker-KhARfCRjLGs.webm
# [download] 100% of 895.24KiB in 00:05
# [ffmpeg] Destination: Emma Roberts - Punch Rocker-KhARfCRjLGs.mp3
# Deleting original file Emma Roberts - Punch Rocker-KhARfCRjLGs.webm (pass -k to keep)
# Emma Roberts - Punch Rocker-KhARfCRjLGs.mp3
# [youtube] -IPTklX5st0: Downloading webpage
# [download] Destination: Darin - Who's that girl--IPTklX5st0.webm
# [download] 100% of 1.60MiB in 00:05
# [ffmpeg] Destination: Darin - Who's that girl--IPTklX5st0.mp3
# Deleting original file Darin - Who's that girl--IPTklX5st0.webm (pass -k to keep)
# Darin - Who's that girl--IPTklX5st0.mp3
# [youtube] eFSNFPcxbMw: Downloading webpage
# [download] Destination: For You I Will (Confidence) by - Teddy Geiger _Lyrics-eFSNFPcxbMw.webm
# [download] 100% of 3.56MiB in 00:07
# [ffmpeg] Destination: For You I Will (Confidence) by - Teddy Geiger _Lyrics-eFSNFPcxbMw.mp3
# Deleting original file For You I Will (Confidence) by - Teddy Geiger _Lyrics-eFSNFPcxbMw.webm (pass -k to keep)
# For You I Will (Confidence) by - Teddy Geiger _Lyrics-eFSNFPcxbMw.mp3
# [youtube] 3gh7CZri-30: Downloading webpage
# [download] Destination: Teddy Geiger- Seven days without you-3gh7CZri-30.webm
# [download] 100% of 1.24MiB in 00:05
# [ffmpeg] Destination: Teddy Geiger- Seven days without you-3gh7CZri-30.mp3
# Deleting original file Teddy Geiger- Seven days without you-3gh7CZri-30.webm (pass -k to keep)
# Teddy Geiger- Seven days without you-3gh7CZri-30.mp3
# [youtube] XcrZwCb0yao: Downloading webpage
# [download] Destination: Love is a marathon by Teddy Geiger-XcrZwCb0yao.webm
# [download] 100% of 1.48MiB in 00:05
# [ffmpeg] Destination: Love is a marathon by Teddy Geiger-XcrZwCb0yao.mp3
# Deleting original file Love is a marathon by Teddy Geiger-XcrZwCb0yao.webm (pass -k to keep)
# Love is a marathon by Teddy Geiger-XcrZwCb0yao.mp3
# [youtube] jgnoeFbK6Co: Downloading webpage
# [download] Destination: Martina McBride- True Love Ways (Lyrics)-jgnoeFbK6Co.m4a
# [download] 100% of 3.11MiB in 00:08
# [ffmpeg] Destination: Martina McBride- True Love Ways (Lyrics)-jgnoeFbK6Co.mp3
# Deleting original file Martina McBride- True Love Ways (Lyrics)-jgnoeFbK6Co.m4a (pass -k to keep)
# Martina McBride- True Love Ways (Lyrics)-jgnoeFbK6Co.mp3
# [youtube] tUy3yby5_Rk: Downloading webpage
# [download] Destination: Martina McBride - I'll Be There.-tUy3yby5_Rk.m4a
# [download] 100% of 2.10MiB in 00:06
# [ffmpeg] Destination: Martina McBride - I'll Be There.-tUy3yby5_Rk.mp3
# Deleting original file Martina McBride - I'll Be There.-tUy3yby5_Rk.m4a (pass -k to keep)
# Martina McBride - I'll Be There.-tUy3yby5_Rk.mp3
# [youtube] c0SrxSMHDmE: Downloading webpage
# [download] Destination: Bullet For My Valentine - Hand Of Blood (Official Music Video)-c0SrxSMHDmE.webm
# [download] 100% of 1.21MiB in 00:05
# [ffmpeg] Destination: Bullet For My Valentine - Hand Of Blood (Official Music Video)-c0SrxSMHDmE.mp3
# Deleting original file Bullet For My Valentine - Hand Of Blood (Official Music Video)-c0SrxSMHDmE.webm (pass -k to keep)
# Bullet For My Valentine - Hand Of Blood (Official Music Video)-c0SrxSMHDmE.mp3
# [youtube] 9pn3R8xa-v4: Downloading webpage
# [download] Destination: Charlotte Church - Even God-9pn3R8xa-v4.webm
# [download] 100% of 1.26MiB in 00:04
# [ffmpeg] Destination: Charlotte Church - Even God-9pn3R8xa-v4.mp3
# Deleting original file Charlotte Church - Even God-9pn3R8xa-v4.webm (pass -k to keep)
# Charlotte Church - Even God-9pn3R8xa-v4.mp3
# [youtube] i5LvVUBXv4k: Downloading webpage
# [download] Destination: These Walls - Teddy Geiger-i5LvVUBXv4k.webm
# [download] 100% of 1.27MiB in 00:04
# [ffmpeg] Destination: These Walls - Teddy Geiger-i5LvVUBXv4k.mp3
# Deleting original file These Walls - Teddy Geiger-i5LvVUBXv4k.webm (pass -k to keep)
# These Walls - Teddy Geiger-i5LvVUBXv4k.mp3
# [youtube] Va0FdsopJSI: Downloading webpage
# [download] Destination: Charlotte Church - Call My Name (Video)-Va0FdsopJSI.webm
# [download] 100% of 1.50MiB in 00:04
# [ffmpeg] Destination: Charlotte Church - Call My Name (Video)-Va0FdsopJSI.mp3
# Deleting original file Charlotte Church - Call My Name (Video)-Va0FdsopJSI.webm (pass -k to keep)
# Charlotte Church - Call My Name (Video)-Va0FdsopJSI.mp3
# [youtube] JDTstRivXSo: Downloading webpage
# [download] Destination: Charlotte Church-Show a Little Faith-JDTstRivXSo.webm
# [download] 100% of 1.55MiB in 00:05
# [ffmpeg] Destination: Charlotte Church-Show a Little Faith-JDTstRivXSo.mp3
# Deleting original file Charlotte Church-Show a Little Faith-JDTstRivXSo.webm (pass -k to keep)
# Charlotte Church-Show a Little Faith-JDTstRivXSo.mp3
# [youtube] t7lPLwtIHMs: Downloading webpage
# [download] Destination: Montgomery Gentry - Hell Yeah (Video)-t7lPLwtIHMs.webm
# [download] 100% of 1.59MiB in 00:06
# [ffmpeg] Destination: Montgomery Gentry - Hell Yeah (Video)-t7lPLwtIHMs.mp3
# Deleting original file Montgomery Gentry - Hell Yeah (Video)-t7lPLwtIHMs.webm (pass -k to keep)
# Montgomery Gentry - Hell Yeah (Video)-t7lPLwtIHMs.mp3
# [youtube] Xi22dVn-B14: Downloading webpage
# [download] Destination: Three 6 Mafia - Late Nite Tip (Official Video)-Xi22dVn-B14.webm
# [download] 100% of 1.53MiB in 00:04
# [ffmpeg] Destination: Three 6 Mafia - Late Nite Tip (Official Video)-Xi22dVn-B14.mp3
# Deleting original file Three 6 Mafia - Late Nite Tip (Official Video)-Xi22dVn-B14.webm (pass -k to keep)
# Three 6 Mafia - Late Nite Tip (Official Video)-Xi22dVn-B14.mp3
# [youtube] 5KLruiHP8U8: Downloading webpage
# [download] Destination: Eurythmics - Never Gonna Cry Again-5KLruiHP8U8.webm
# [download] 100% of 1.23MiB in 00:05
# [ffmpeg] Destination: Eurythmics - Never Gonna Cry Again-5KLruiHP8U8.mp3
# Deleting original file Eurythmics - Never Gonna Cry Again-5KLruiHP8U8.webm (pass -k to keep)
# Eurythmics - Never Gonna Cry Again-5KLruiHP8U8.mp3
# [youtube] 1kIk1S0S3QA: Downloading webpage
# [download] Destination: Michael Bolton - A Love So Beautiful  'HQ'-1kIk1S0S3QA.webm
# [download] 100% of 1.14MiB in 00:01
# [ffmpeg] Destination: Michael Bolton - A Love So Beautiful  'HQ'-1kIk1S0S3QA.mp3
# Deleting original file Michael Bolton - A Love So Beautiful  'HQ'-1kIk1S0S3QA.webm (pass -k to keep)
# Michael Bolton - A Love So Beautiful  'HQ'-1kIk1S0S3QA.mp3
# [youtube] _AmkmqYEarw: Downloading webpage
# [download] Destination: Eurythmics, Annie Lennox, Dave Stewart - Thorn In My Side (Official Video)-_AmkmqYEarw.webm
# [download] 100% of 1.48MiB in 00:04
# [ffmpeg] Destination: Eurythmics, Annie Lennox, Dave Stewart - Thorn In My Side (Official Video)-_AmkmqYEarw.mp3
# Deleting original file Eurythmics, Annie Lennox, Dave Stewart - Thorn In My Side (Official Video)-_AmkmqYEarw.webm (pass -k to keep)
# Eurythmics, Annie Lennox, Dave Stewart - Thorn In My Side (Official Video)-_AmkmqYEarw.mp3
# [youtube] Kc71KZG87X4: Downloading webpage
# [download] Destination: Survivor - Burning Heart (Video)-Kc71KZG87X4.webm
# [download] 100% of 1.31MiB in 00:02
# [ffmpeg] Destination: Survivor - Burning Heart (Video)-Kc71KZG87X4.mp3
# Deleting original file Survivor - Burning Heart (Video)-Kc71KZG87X4.webm (pass -k to keep)
# Survivor - Burning Heart (Video)-Kc71KZG87X4.mp3
# [youtube] YFood_bTOX4: Downloading webpage
# [download] Destination: Michael Bolton - How Am I Supposed To Live Without You-YFood_bTOX4.webm
# [download] 100% of 1.52MiB in 00:01
# [ffmpeg] Destination: Michael Bolton - How Am I Supposed To Live Without You-YFood_bTOX4.mp3
# Deleting original file Michael Bolton - How Am I Supposed To Live Without You-YFood_bTOX4.webm (pass -k to keep)
# Michael Bolton - How Am I Supposed To Live Without You-YFood_bTOX4.mp3
# [youtube] pT68FS3YbQ4: Downloading webpage
# [download] Destination: The Strokes - You Only Live Once (Official Music Video)-pT68FS3YbQ4.webm
# [download] 100% of 1.08MiB in 00:04
# [ffmpeg] Destination: The Strokes - You Only Live Once (Official Music Video)-pT68FS3YbQ4.mp3
# Deleting original file The Strokes - You Only Live Once (Official Music Video)-pT68FS3YbQ4.webm (pass -k to keep)
# The Strokes - You Only Live Once (Official Music Video)-pT68FS3YbQ4.mp3
# [youtube] EvoCUKncQR8: Downloading webpage
# [download] Destination: Our Lady Peace - Wipe That Smile Off Your Face (Live in Toronto) (Official Audio)-EvoCUKncQR8.webm
# [download] 100% of 3.95MiB in 00:07
# [ffmpeg] Destination: Our Lady Peace - Wipe That Smile Off Your Face (Live in Toronto) (Official Audio)-EvoCUKncQR8.mp3
# Deleting original file Our Lady Peace - Wipe That Smile Off Your Face (Live in Toronto) (Official Audio)-EvoCUKncQR8.webm (pass -k to keep)
# Our Lady Peace - Wipe That Smile Off Your Face (Live in Toronto) (Official Audio)-EvoCUKncQR8.mp3
# [youtube] G0muzRg6Dbw: Downloading webpage
# [download] Destination: Our Lady Peace - Apology (Official Audio)-G0muzRg6Dbw.m4a
# [download] 100% of 3.53MiB in 00:09
# [ffmpeg] Destination: Our Lady Peace - Apology (Official Audio)-G0muzRg6Dbw.mp3
# Deleting original file Our Lady Peace - Apology (Official Audio)-G0muzRg6Dbw.m4a (pass -k to keep)
# Our Lady Peace - Apology (Official Audio)-G0muzRg6Dbw.mp3
# [youtube] e4QKuy1MS1E: Downloading webpage
# [download] Destination: Sarah Mclachlan - Time-e4QKuy1MS1E.webm
# [download] 100% of 1.64MiB in 00:04
# [ffmpeg] Destination: Sarah Mclachlan - Time-e4QKuy1MS1E.mp3
# Deleting original file Sarah Mclachlan - Time-e4QKuy1MS1E.webm (pass -k to keep)
# Sarah Mclachlan - Time-e4QKuy1MS1E.mp3
# [youtube] wi2OtVprD1o: Downloading webpage
# [download] Destination: Cyndi Lauper - Water's Edge-wi2OtVprD1o.webm
# [download] 100% of 1.82MiB in 00:07
# [ffmpeg] Destination: Cyndi Lauper - Water's Edge-wi2OtVprD1o.mp3
# Deleting original file Cyndi Lauper - Water's Edge-wi2OtVprD1o.webm (pass -k to keep)
# Cyndi Lauper - Water's Edge-wi2OtVprD1o.mp3
# [youtube] DaSPa2KNvjk: Downloading webpage
# [download] Destination: Train - All I Ever Wanted-DaSPa2KNvjk.webm
# [download] 100% of 1.53MiB in 00:06
# [ffmpeg] Destination: Train - All I Ever Wanted-DaSPa2KNvjk.mp3
# Deleting original file Train - All I Ever Wanted-DaSPa2KNvjk.webm (pass -k to keep)
# Train - All I Ever Wanted-DaSPa2KNvjk.mp3
# [youtube] EemknZY3Il8: Downloading webpage
# [download] Destination: Train - For Me It's You Lyrics-EemknZY3Il8.webm
# [download] 100% of 1.85MiB in 00:06
# [ffmpeg] Destination: Train - For Me It's You Lyrics-EemknZY3Il8.mp3
# Deleting original file Train - For Me It's You Lyrics-EemknZY3Il8.webm (pass -k to keep)
# Train - For Me It's You Lyrics-EemknZY3Il8.mp3
# [youtube] EjBrIBMA8Bw: Downloading webpage
# [download] Destination: Say Anything - Belt-EjBrIBMA8Bw.webm
# [download] 100% of 1.70MiB in 00:05
# [ffmpeg] Destination: Say Anything - Belt-EjBrIBMA8Bw.mp3
# Deleting original file Say Anything - Belt-EjBrIBMA8Bw.webm (pass -k to keep)
# Say Anything - Belt-EjBrIBMA8Bw.mp3
# [youtube] Z37lCE3ZHHM: Downloading webpage
# [download] Destination: Say Anything - An Orgy Of Critics-Z37lCE3ZHHM.webm
# [download] 100% of 1.33MiB in 00:04
# [ffmpeg] Destination: Say Anything - An Orgy Of Critics-Z37lCE3ZHHM.mp3
# Deleting original file Say Anything - An Orgy Of Critics-Z37lCE3ZHHM.webm (pass -k to keep)
# Say Anything - An Orgy Of Critics-Z37lCE3ZHHM.mp3
# [youtube] 8nvpRkn_R5g: Downloading webpage
# [download] Destination: Living Colour - Elvis Is Dead-8nvpRkn_R5g.webm
# [download] 100% of 1.40MiB in 00:04
# [ffmpeg] Destination: Living Colour - Elvis Is Dead-8nvpRkn_R5g.mp3
# Deleting original file Living Colour - Elvis Is Dead-8nvpRkn_R5g.webm (pass -k to keep)
# Living Colour - Elvis Is Dead-8nvpRkn_R5g.mp3
# [youtube] oOspVvoWCB0: Downloading webpage
# [download] Destination: Have Yourself A Merry Little Christmas _ Sarah McLachlan-oOspVvoWCB0.webm
# [download] 100% of 1.41MiB in 00:05
# [ffmpeg] Destination: Have Yourself A Merry Little Christmas _ Sarah McLachlan-oOspVvoWCB0.mp3
# Deleting original file Have Yourself A Merry Little Christmas _ Sarah McLachlan-oOspVvoWCB0.webm (pass -k to keep)
# Have Yourself A Merry Little Christmas _ Sarah McLachlan-oOspVvoWCB0.mp3
# [youtube] 5Xp4iIQuhd4: Downloading webpage
# [download] Destination: Foo Fighters - Razor-5Xp4iIQuhd4.webm
# [download] 100% of 1.89MiB in 00:05
# [ffmpeg] Destination: Foo Fighters - Razor-5Xp4iIQuhd4.mp3
# Deleting original file Foo Fighters - Razor-5Xp4iIQuhd4.webm (pass -k to keep)
# Foo Fighters - Razor-5Xp4iIQuhd4.mp3
# [youtube] KY0C7rZeUew: Downloading webpage
# [download] Destination: Foo Fighters - Another Round-KY0C7rZeUew.webm
# [download] 100% of 1.92MiB in 00:05
# [ffmpeg] Destination: Foo Fighters - Another Round-KY0C7rZeUew.mp3
# Deleting original file Foo Fighters - Another Round-KY0C7rZeUew.webm (pass -k to keep)
# Foo Fighters - Another Round-KY0C7rZeUew.mp3
# [youtube] 840bkF0KAws: Downloading webpage
# [download] Destination: Foo Fighters - Ain't It The Life (from Skin And Bones, Live in Hollywood, 2006)-840bkF0KAws.webm
# [download] 100% of 1.74MiB in 00:05
# [ffmpeg] Destination: Foo Fighters - Ain't It The Life (from Skin And Bones, Live in Hollywood, 2006)-840bkF0KAws.mp3
# Deleting original file Foo Fighters - Ain't It The Life (from Skin And Bones, Live in Hollywood, 2006)-840bkF0KAws.webm (pass -k to keep)
# Foo Fighters - Ain't It The Life (from Skin And Bones, Live in Hollywood, 2006)-840bkF0KAws.mp3
# [youtube] d5KtEQT3ncE: Downloading webpage
# [download] Destination: DJ Quik - Summer Breeze-d5KtEQT3ncE.webm
# [download] 100% of 1.62MiB in 00:05
# [ffmpeg] Destination: DJ Quik - Summer Breeze-d5KtEQT3ncE.mp3
# Deleting original file DJ Quik - Summer Breeze-d5KtEQT3ncE.webm (pass -k to keep)
# DJ Quik - Summer Breeze-d5KtEQT3ncE.mp3
# [youtube] 9Vpd0KUezlk: Downloading webpage
# [download] Destination: Tanya Tucker -  What's  Your Mama's Name, Child-9Vpd0KUezlk.webm
# [download] 100% of 1.15MiB in 00:04
# [ffmpeg] Destination: Tanya Tucker -  What's  Your Mama's Name, Child-9Vpd0KUezlk.mp3
# Deleting original file Tanya Tucker -  What's  Your Mama's Name, Child-9Vpd0KUezlk.webm (pass -k to keep)
# Tanya Tucker -  What's  Your Mama's Name, Child-9Vpd0KUezlk.mp3
# [youtube] qYkbTyHXwbs: Downloading webpage
# [download] Destination: Rick Springfield - Jessie's Girl (Official Video)-qYkbTyHXwbs.webm
# [download] 100% of 998.24KiB in 00:13
# [ffmpeg] Destination: Rick Springfield - Jessie's Girl (Official Video)-qYkbTyHXwbs.mp3
# Deleting original file Rick Springfield - Jessie's Girl (Official Video)-qYkbTyHXwbs.webm (pass -k to keep)
# Rick Springfield - Jessie's Girl (Official Video)-qYkbTyHXwbs.mp3
# [youtube] aJkjmJD5-bo: Downloading webpage
# [download] Destination: Jessica Simpson - 05. Walkin' Round in A Circle (Lyrics)-aJkjmJD5-bo.m4a
# [download] 100% of 4.25MiB in 00:16
# [ffmpeg] Destination: Jessica Simpson - 05. Walkin' Round in A Circle (Lyrics)-aJkjmJD5-bo.mp3
# Deleting original file Jessica Simpson - 05. Walkin' Round in A Circle (Lyrics)-aJkjmJD5-bo.m4a (pass -k to keep)
# Jessica Simpson - 05. Walkin' Round in A Circle (Lyrics)-aJkjmJD5-bo.mp3
# [youtube] LbcpecJxPq8: Downloading webpage
# [download] Destination: Jessica Simpson - 08. Push Your Tush (Lyrics)-LbcpecJxPq8.m4a
# [download] 100% of 4.36MiB in 00:07
# [ffmpeg] Destination: Jessica Simpson - 08. Push Your Tush (Lyrics)-LbcpecJxPq8.mp3
# Deleting original file Jessica Simpson - 08. Push Your Tush (Lyrics)-LbcpecJxPq8.m4a (pass -k to keep)
# Jessica Simpson - 08. Push Your Tush (Lyrics)-LbcpecJxPq8.mp3
# [youtube] BqfnXTUfkPs: Downloading webpage
# [download] Destination: Jessica Simpson - 11. I Don't Want To Care (Lyrics)-BqfnXTUfkPs.m4a
# [download] 100% of 3.59MiB in 00:05
# [ffmpeg] Destination: Jessica Simpson - 11. I Don't Want To Care (Lyrics)-BqfnXTUfkPs.mp3
# Deleting original file Jessica Simpson - 11. I Don't Want To Care (Lyrics)-BqfnXTUfkPs.m4a (pass -k to keep)
# Jessica Simpson - 11. I Don't Want To Care (Lyrics)-BqfnXTUfkPs.mp3
# [youtube] sndTlyHs-P4: Downloading webpage
# [download] Destination: Jessica Simpson - 13. Let Him Fly (Lyrics)-sndTlyHs-P4.m4a
# [download] 100% of 2.91MiB in 00:05
# [ffmpeg] Destination: Jessica Simpson - 13. Let Him Fly (Lyrics)-sndTlyHs-P4.mp3
# Deleting original file Jessica Simpson - 13. Let Him Fly (Lyrics)-sndTlyHs-P4.m4a (pass -k to keep)
# Jessica Simpson - 13. Let Him Fly (Lyrics)-sndTlyHs-P4.mp3
# [youtube] IxkJHX7ukKE: Downloading webpage
# [download] Destination: Michael Penn - No Myth-IxkJHX7ukKE.webm
# [download] 100% of 1.52MiB in 00:06
# [ffmpeg] Destination: Michael Penn - No Myth-IxkJHX7ukKE.mp3
# Deleting original file Michael Penn - No Myth-IxkJHX7ukKE.webm (pass -k to keep)
# Michael Penn - No Myth-IxkJHX7ukKE.mp3
# [youtube] iWGL3mPE114: Downloading webpage
# [download] Destination: Michael Penn - Walter Reed-iWGL3mPE114.webm
# [download] 100% of 1.36MiB in 00:04
# [ffmpeg] Destination: Michael Penn - Walter Reed-iWGL3mPE114.mp3
# Deleting original file Michael Penn - Walter Reed-iWGL3mPE114.webm (pass -k to keep)
# Michael Penn - Walter Reed-iWGL3mPE114.mp3
# [youtube] Vjw92oUduEM: Downloading webpage
# [download] Destination: Destiny's Child - Jumpin’ Jumpin’ (Official Music Video)-Vjw92oUduEM.webm
# [download] 100% of 1.34MiB in 00:04
# [ffmpeg] Destination: Destiny's Child - Jumpin’ Jumpin’ (Official Music Video)-Vjw92oUduEM.mp3
# Deleting original file Destiny's Child - Jumpin’ Jumpin’ (Official Music Video)-Vjw92oUduEM.webm (pass -k to keep)
# Destiny's Child - Jumpin’ Jumpin’ (Official Music Video)-Vjw92oUduEM.mp3
# [youtube] HTgKEsY9_sw: Downloading webpage
# [download] Destination: The Zutons - Oh Stacey (Look What You've Done!) (Video)-HTgKEsY9_sw.webm
# [download] 100% of 1.30MiB in 00:04
# [ffmpeg] Destination: The Zutons - Oh Stacey (Look What You've Done!) (Video)-HTgKEsY9_sw.mp3
# Deleting original file The Zutons - Oh Stacey (Look What You've Done!) (Video)-HTgKEsY9_sw.webm (pass -k to keep)
# The Zutons - Oh Stacey (Look What You've Done!) (Video)-HTgKEsY9_sw.mp3
# [youtube] 4jgIbVK7C4k: Downloading webpage
# [download] Destination: Clannad - Something to Believe In (Official Music Video)-4jgIbVK7C4k.webm
# [download] 100% of 1.33MiB in 00:05
# [ffmpeg] Destination: Clannad - Something to Believe In (Official Music Video)-4jgIbVK7C4k.mp3
# Deleting original file Clannad - Something to Believe In (Official Music Video)-4jgIbVK7C4k.webm (pass -k to keep)
# Clannad - Something to Believe In (Official Music Video)-4jgIbVK7C4k.mp3
# [youtube] aFKNiAVw5mQ: Downloading webpage
# [download] Destination: Feel what I feel--Kat DeLuna-aFKNiAVw5mQ.webm
# [download] 100% of 1.41MiB in 01:43
# [ffmpeg] Destination: Feel what I feel--Kat DeLuna-aFKNiAVw5mQ.mp3
# Deleting original file Feel what I feel--Kat DeLuna-aFKNiAVw5mQ.webm (pass -k to keep)
# Feel what I feel--Kat DeLuna-aFKNiAVw5mQ.mp3
# [youtube] jcMXZjYqIog: Downloading webpage
# [download] Destination: Kat DeLuna - Whine Up (Official Video) ft. Elephant Man-jcMXZjYqIog.webm
# [download] 100% of 1.50MiB in 00:04
# [ffmpeg] Destination: Kat DeLuna - Whine Up (Official Video) ft. Elephant Man-jcMXZjYqIog.mp3
# Deleting original file Kat DeLuna - Whine Up (Official Video) ft. Elephant Man-jcMXZjYqIog.webm (pass -k to keep)
# Kat DeLuna - Whine Up (Official Video) ft. Elephant Man-jcMXZjYqIog.mp3
# [youtube] nBacckhivxc: Downloading webpage
# [download] Destination: ♥ ♥ Love me Leave me  ♥ ♥ Kat DeLuna-nBacckhivxc.webm
# [download] 100% of 1.55MiB in 00:23
# [ffmpeg] Destination: ♥ ♥ Love me Leave me  ♥ ♥ Kat DeLuna-nBacckhivxc.mp3
# Deleting original file ♥ ♥ Love me Leave me  ♥ ♥ Kat DeLuna-nBacckhivxc.webm (pass -k to keep)
# ♥ ♥ Love me Leave me  ♥ ♥ Kat DeLuna-nBacckhivxc.mp3
# [youtube] CcoLD7IrK00: Downloading webpage
# [download] Destination: Kat DeLuna - Enjoy Saying Goodbye-CcoLD7IrK00.m4a
# [download] 100% of 3.73MiB in 00:09
# [ffmpeg] Destination: Kat DeLuna - Enjoy Saying Goodbye-CcoLD7IrK00.mp3
# Deleting original file Kat DeLuna - Enjoy Saying Goodbye-CcoLD7IrK00.m4a (pass -k to keep)
# Kat DeLuna - Enjoy Saying Goodbye-CcoLD7IrK00.mp3
# [youtube] DAX20LoVgxE: Downloading webpage
# [download] Destination: Warrant - Sometimes She Cries (Official Video)-DAX20LoVgxE.webm
# [download] 100% of 1.48MiB in 00:04
# [ffmpeg] Destination: Warrant - Sometimes She Cries (Official Video)-DAX20LoVgxE.mp3
# Deleting original file Warrant - Sometimes She Cries (Official Video)-DAX20LoVgxE.webm (pass -k to keep)
# Warrant - Sometimes She Cries (Official Video)-DAX20LoVgxE.mp3
# [youtube] rrSdXtFJG20: Downloading webpage
# [download] Destination: Warrant - Heaven (Official Video)-rrSdXtFJG20.webm
# [download] 100% of 1.49MiB in 00:43
# [ffmpeg] Destination: Warrant - Heaven (Official Video)-rrSdXtFJG20.mp3
# Deleting original file Warrant - Heaven (Official Video)-rrSdXtFJG20.webm (pass -k to keep)
# Warrant - Heaven (Official Video)-rrSdXtFJG20.mp3
# [youtube] noufF7bqkq4: Downloading webpage
# [download] Destination: Modest Mouse - Blame It On the Tetons (Lyrics)-noufF7bqkq4.webm
# [download] 100% of 1.99MiB in 00:06
# [ffmpeg] Destination: Modest Mouse - Blame It On the Tetons (Lyrics)-noufF7bqkq4.mp3
# Deleting original file Modest Mouse - Blame It On the Tetons (Lyrics)-noufF7bqkq4.webm (pass -k to keep)
# Modest Mouse - Blame It On the Tetons (Lyrics)-noufF7bqkq4.mp3
# [youtube] CTAud5O7Qqk: Downloading webpage
# [download] Destination: Modest Mouse - Float On (Official Music Video)-CTAud5O7Qqk.webm
# [download] 100% of 1.33MiB in 00:05
# [ffmpeg] Destination: Modest Mouse - Float On (Official Music Video)-CTAud5O7Qqk.mp3
# Deleting original file Modest Mouse - Float On (Official Music Video)-CTAud5O7Qqk.webm (pass -k to keep)
# Modest Mouse - Float On (Official Music Video)-CTAud5O7Qqk.mp3
# [youtube] Wt5EHAqhR1c: Downloading webpage
# [download] Destination: Ben Folds Five - Brick (Official Video)-Wt5EHAqhR1c.webm
# [download] 100% of 1.77MiB in 00:05
# [ffmpeg] Destination: Ben Folds Five - Brick (Official Video)-Wt5EHAqhR1c.mp3
# Deleting original file Ben Folds Five - Brick (Official Video)-Wt5EHAqhR1c.webm (pass -k to keep)
# Ben Folds Five - Brick (Official Video)-Wt5EHAqhR1c.mp3
# [youtube] ju_a2-Pve4g: Downloading webpage
# [download] Destination: Paul Young - Wherever I Lay My Hat (That's My Home)-ju_a2-Pve4g.webm
# [download] 100% of 1.56MiB in 00:05
# [ffmpeg] Destination: Paul Young - Wherever I Lay My Hat (That's My Home)-ju_a2-Pve4g.mp3
# Deleting original file Paul Young - Wherever I Lay My Hat (That's My Home)-ju_a2-Pve4g.webm (pass -k to keep)
# Paul Young - Wherever I Lay My Hat (That's My Home)-ju_a2-Pve4g.mp3
# [youtube] fVhZPbyn3is: Downloading webpage
# [download] Destination: Ben Folds Five - Mitchell Lane-fVhZPbyn3is.webm
# [download] 100% of 1.37MiB in 00:06
# [ffmpeg] Destination: Ben Folds Five - Mitchell Lane-fVhZPbyn3is.mp3
# Deleting original file Ben Folds Five - Mitchell Lane-fVhZPbyn3is.webm (pass -k to keep)
# Ben Folds Five - Mitchell Lane-fVhZPbyn3is.mp3
# [youtube] jGoM7atmJJA: Downloading webpage
# [download] Destination: Britney Spears - Don't Let Me Be The Last To Know (Official HD Video)-jGoM7atmJJA.webm
# [download] 100% of 1.42MiB in 00:55
# [ffmpeg] Destination: Britney Spears - Don't Let Me Be The Last To Know (Official HD Video)-jGoM7atmJJA.mp3
# Deleting original file Britney Spears - Don't Let Me Be The Last To Know (Official HD Video)-jGoM7atmJJA.webm (pass -k to keep)
# Britney Spears - Don't Let Me Be The Last To Know (Official HD Video)-jGoM7atmJJA.mp3
# [youtube] dIOH8Trfas4: Downloading webpage
# [download] Destination: Britney Spears - My Prerogative (Official Video)-dIOH8Trfas4.webm
# [download] 100% of 1.30MiB in 00:06
# [ffmpeg] Destination: Britney Spears - My Prerogative (Official Video)-dIOH8Trfas4.mp3
# Deleting original file Britney Spears - My Prerogative (Official Video)-dIOH8Trfas4.webm (pass -k to keep)
# Britney Spears - My Prerogative (Official Video)-dIOH8Trfas4.mp3
# [youtube] LOZuxwVk7TU: Downloading webpage
# [download] Destination: Britney Spears - Toxic (Official Video)-LOZuxwVk7TU.webm
# [download] 100% of 1.24MiB in 00:03
# [ffmpeg] Destination: Britney Spears - Toxic (Official Video)-LOZuxwVk7TU.mp3
# Deleting original file Britney Spears - Toxic (Official Video)-LOZuxwVk7TU.webm (pass -k to keep)
# Britney Spears - Toxic (Official Video)-LOZuxwVk7TU.mp3
# [youtube] CduA0TULnow: Downloading webpage
# [download] Destination: Britney Spears - Oops!...I Did It Again (Official Video)-CduA0TULnow.webm
# [download] 100% of 1.45MiB in 00:02
# [ffmpeg] Destination: Britney Spears - Oops!...I Did It Again (Official Video)-CduA0TULnow.mp3
# Deleting original file Britney Spears - Oops!...I Did It Again (Official Video)-CduA0TULnow.webm (pass -k to keep)
# Britney Spears - Oops!...I Did It Again (Official Video)-CduA0TULnow.mp3
# [youtube] SYFmW9ezPyA: Downloading webpage
# [download] Destination: (You Drive Me) Crazy [The Stop Remix] - Britney Spears-SYFmW9ezPyA.webm
# [download] 100% of 1.12MiB in 00:04
# [ffmpeg] Destination: (You Drive Me) Crazy [The Stop Remix] - Britney Spears-SYFmW9ezPyA.mp3
# Deleting original file (You Drive Me) Crazy [The Stop Remix] - Britney Spears-SYFmW9ezPyA.webm (pass -k to keep)
# (You Drive Me) Crazy [The Stop Remix] - Britney Spears-SYFmW9ezPyA.mp3
# [youtube] 4vvBAONkYwI: Downloading webpage
# [download] Destination: Britney Spears - Lucky (Official Video)-4vvBAONkYwI.webm
# [download] 100% of 1.40MiB in 00:05
# [ffmpeg] Destination: Britney Spears - Lucky (Official Video)-4vvBAONkYwI.mp3
# Deleting original file Britney Spears - Lucky (Official Video)-4vvBAONkYwI.webm (pass -k to keep)
# Britney Spears - Lucky (Official Video)-4vvBAONkYwI.mp3
# [youtube] Yy5cKX4jBkQ: Downloading webpage
# [download] Destination: Britney Spears - Born To Make You Happy (Official HD Video)-Yy5cKX4jBkQ.webm
# [download] 100% of 1.29MiB in 00:03
# [ffmpeg] Destination: Britney Spears - Born To Make You Happy (Official HD Video)-Yy5cKX4jBkQ.mp3
# Deleting original file Britney Spears - Born To Make You Happy (Official HD Video)-Yy5cKX4jBkQ.webm (pass -k to keep)
# Britney Spears - Born To Make You Happy (Official HD Video)-Yy5cKX4jBkQ.mp3
# [youtube] Vunxecrm6CI: Downloading webpage
# [download] Destination: Britney Spears - Do Somethin' (Official Music Video)-Vunxecrm6CI.webm
# [download] 100% of 1.18MiB in 00:05
# [ffmpeg] Destination: Britney Spears - Do Somethin' (Official Music Video)-Vunxecrm6CI.mp3
# Deleting original file Britney Spears - Do Somethin' (Official Music Video)-Vunxecrm6CI.webm (pass -k to keep)
# Britney Spears - Do Somethin' (Official Music Video)-Vunxecrm6CI.mp3
# [youtube] AJWtLf4-WWs: Downloading webpage
# [download] Destination: Britney Spears - Stronger (Official Video)-AJWtLf4-WWs.webm
# [download] 100% of 1.42MiB in 00:03
# [ffmpeg] Destination: Britney Spears - Stronger (Official Video)-AJWtLf4-WWs.mp3
# Deleting original file Britney Spears - Stronger (Official Video)-AJWtLf4-WWs.webm (pass -k to keep)
# Britney Spears - Stronger (Official Video)-AJWtLf4-WWs.mp3
# [youtube] WLPeRDJGKvQ: Downloading webpage
# [download] Destination: Paul Young - Everything Must Change (Official HD Video)-WLPeRDJGKvQ.webm
# [download] 100% of 1.57MiB in 00:06
# [ffmpeg] Destination: Paul Young - Everything Must Change (Official HD Video)-WLPeRDJGKvQ.mp3
# Deleting original file Paul Young - Everything Must Change (Official HD Video)-WLPeRDJGKvQ.webm (pass -k to keep)
# Paul Young - Everything Must Change (Official HD Video)-WLPeRDJGKvQ.mp3
# [youtube] aeeJhEpeUfc: Downloading webpage
# [download] Destination: Paul Young - Come Back and Stay (Official Music Video)-aeeJhEpeUfc.webm
# [download] 100% of 1.72MiB in 02:19
# [ffmpeg] Destination: Paul Young - Come Back and Stay (Official Music Video)-aeeJhEpeUfc.mp3
# Deleting original file Paul Young - Come Back and Stay (Official Music Video)-aeeJhEpeUfc.webm (pass -k to keep)
# Paul Young - Come Back and Stay (Official Music Video)-aeeJhEpeUfc.mp3
# [youtube] I0gO2kdtHd4: Downloading webpage
# [download] Destination: Matisyahu - Indestructible-I0gO2kdtHd4.webm
# [download] 100% of 1.57MiB in 00:15
# [ffmpeg] Destination: Matisyahu - Indestructible-I0gO2kdtHd4.mp3
# Deleting original file Matisyahu - Indestructible-I0gO2kdtHd4.webm (pass -k to keep)
# Matisyahu - Indestructible-I0gO2kdtHd4.mp3
# [youtube] oCzRkA-RE4k: Downloading webpage
# [download] Destination: Matisyahu - Ancient Lullaby-oCzRkA-RE4k.webm
# [download] 100% of 1.60MiB in 00:05
# [ffmpeg] Destination: Matisyahu - Ancient Lullaby-oCzRkA-RE4k.mp3
# Deleting original file Matisyahu - Ancient Lullaby-oCzRkA-RE4k.webm (pass -k to keep)
# Matisyahu - Ancient Lullaby-oCzRkA-RE4k.mp3
# [youtube] Y4Eq2lk_fwA: Downloading webpage
# [download] Destination: Living Things - Bom Bom Bom-Y4Eq2lk_fwA.webm
# [download] 100% of 1.12MiB in 00:06
# [ffmpeg] Destination: Living Things - Bom Bom Bom-Y4Eq2lk_fwA.mp3
# Deleting original file Living Things - Bom Bom Bom-Y4Eq2lk_fwA.webm (pass -k to keep)
# Living Things - Bom Bom Bom-Y4Eq2lk_fwA.mp3
# [youtube] W8c04XHCF8k: Downloading webpage
# [download] Destination: Spagna - Call Me-W8c04XHCF8k.webm
# [download] 100% of 1.40MiB in 00:03
# [ffmpeg] Destination: Spagna - Call Me-W8c04XHCF8k.mp3
# Deleting original file Spagna - Call Me-W8c04XHCF8k.webm (pass -k to keep)
# Spagna - Call Me-W8c04XHCF8k.mp3
# [youtube] IhgFxH4ARrE: Downloading webpage
# [download] Destination: ANTI-FLAG - I'd tell you but-IhgFxH4ARrE.webm
# [download] 100% of 759.45KiB in 00:04
# [ffmpeg] Destination: ANTI-FLAG - I'd tell you but-IhgFxH4ARrE.mp3
# Deleting original file ANTI-FLAG - I'd tell you but-IhgFxH4ARrE.webm (pass -k to keep)
# ANTI-FLAG - I'd tell you but-IhgFxH4ARrE.mp3
# [youtube] e5Wxn37Tt1Y: Downloading webpage
# [download] Destination: Anti-Flag - The Press Corpse-e5Wxn37Tt1Y.webm
# [download] 100% of 1.21MiB in 00:05
# [ffmpeg] Destination: Anti-Flag - The Press Corpse-e5Wxn37Tt1Y.mp3
# Deleting original file Anti-Flag - The Press Corpse-e5Wxn37Tt1Y.webm (pass -k to keep)
# Anti-Flag - The Press Corpse-e5Wxn37Tt1Y.mp3
# [youtube] qnVD7WuarSo: Downloading webpage
# [download] Destination: Anti-Flag - This Is The End (For You My Friend) (Main Video)-qnVD7WuarSo.webm
# [download] 100% of 1.10MiB in 00:04
# [ffmpeg] Destination: Anti-Flag - This Is The End (For You My Friend) (Main Video)-qnVD7WuarSo.mp3
# Deleting original file Anti-Flag - This Is The End (For You My Friend) (Main Video)-qnVD7WuarSo.webm (pass -k to keep)
# Anti-Flag - This Is The End (For You My Friend) (Main Video)-qnVD7WuarSo.mp3
# [youtube] xELTfJ-ZVBc: Downloading webpage
# [download] Destination: Survivor - The Search Is Over (Video)-xELTfJ-ZVBc.webm
# [download] 100% of 1.62MiB in 02:17
# [ffmpeg] Destination: Survivor - The Search Is Over (Video)-xELTfJ-ZVBc.mp3
# Deleting original file Survivor - The Search Is Over (Video)-xELTfJ-ZVBc.webm (pass -k to keep)
# Survivor - The Search Is Over (Video)-xELTfJ-ZVBc.mp3
# [youtube] Z34xaDQ3ra4: Downloading webpage
# [download] Destination: GARY PUCKETT and the UNION GAP ~ 'OVER YOU'  HQ STEREO  1968-Z34xaDQ3ra4.webm
# [download] 100% of 957.49KiB in 00:05
# [ffmpeg] Destination: GARY PUCKETT and the UNION GAP ~ 'OVER YOU'  HQ STEREO  1968-Z34xaDQ3ra4.mp3
# Deleting original file GARY PUCKETT and the UNION GAP ~ 'OVER YOU'  HQ STEREO  1968-Z34xaDQ3ra4.webm (pass -k to keep)
# GARY PUCKETT and the UNION GAP ~ 'OVER YOU'  HQ STEREO  1968-Z34xaDQ3ra4.mp3
# [youtube] 86ZXVfdOlGc: Downloading webpage
# [download] Destination: Johnny Mathis  -  99 Miles From L.A-86ZXVfdOlGc.webm
# [download] 100% of 1.28MiB in 00:05
# [ffmpeg] Destination: Johnny Mathis  -  99 Miles From L.A-86ZXVfdOlGc.mp3
# Deleting original file Johnny Mathis  -  99 Miles From L.A-86ZXVfdOlGc.webm (pass -k to keep)
# Johnny Mathis  -  99 Miles From L.A-86ZXVfdOlGc.mp3
# [youtube] kU3mwbMbVs8: Downloading webpage
# [download] Destination: Andy Williams - 'Do You Hear What I Hear'-kU3mwbMbVs8.webm
# [download] 100% of 1.23MiB in 00:05
# [ffmpeg] Destination: Andy Williams - 'Do You Hear What I Hear'-kU3mwbMbVs8.mp3
# Deleting original file Andy Williams - 'Do You Hear What I Hear'-kU3mwbMbVs8.webm (pass -k to keep)
# Andy Williams - 'Do You Hear What I Hear'-kU3mwbMbVs8.mp3
# [youtube] T88fbHOmvRk: Downloading webpage
# [download] Destination: Summer Breeze - The Isley Brothers-T88fbHOmvRk.webm
# [download] 100% of 2.31MiB in 00:04
# [ffmpeg] Destination: Summer Breeze - The Isley Brothers-T88fbHOmvRk.mp3
# Deleting original file Summer Breeze - The Isley Brothers-T88fbHOmvRk.webm (pass -k to keep)
# Summer Breeze - The Isley Brothers-T88fbHOmvRk.mp3
# [youtube] xiWehIIymwE: Downloading webpage
# [download] Destination: Jessica Simpson - Sweetest Sin-xiWehIIymwE.webm
# [download] 100% of 1.10MiB in 00:03
# ...
# [download] 100% of 1.51MiB in 00:04
# [ffmpeg] Destination: Mariah Carey - Anytime You Need A Friend-Li6vpAMmfw0.mp3
# Deleting original file Mariah Carey - Anytime You Need A Friend-Li6vpAMmfw0.webm (pass -k to keep)
# Mariah Carey - Anytime You Need A Friend-Li6vpAMmfw0.mp3
# [youtube] 995kURfKKNg: Downloading webpage
# [download] Destination: Maybe I w_ Lyrics-995kURfKKNg.webm
# [download] 100% of 1.64MiB in 00:05
# [ffmpeg] Destination: Maybe I w_ Lyrics-995kURfKKNg.mp3
# Deleting original file Maybe I w_ Lyrics-995kURfKKNg.webm (pass -k to keep)
# Maybe I w_ Lyrics-995kURfKKNg.mp3
# [youtube] tov22NtCMC4: Downloading webpage
# [download] Destination: Mariah Carey - Vision Of Love-tov22NtCMC4.webm
# [download] 100% of 1.22MiB in 00:12
# [ffmpeg] Destination: Mariah Carey - Vision Of Love-tov22NtCMC4.mp3
# Deleting original file Mariah Carey - Vision Of Love-tov22NtCMC4.webm (pass -k to keep)
# Mariah Carey - Vision Of Love-tov22NtCMC4.mp3
# [youtube] UIt3dx4an9c: Downloading webpage
# [download] Destination: Mariah Carey - I'll Be There (Video)-UIt3dx4an9c.webm
# [download] 100% of 1.59MiB in 00:04
# [ffmpeg] Destination: Mariah Carey - I'll Be There (Video)-UIt3dx4an9c.mp3
# Deleting original file Mariah Carey - I'll Be There (Video)-UIt3dx4an9c.webm (pass -k to keep)
# Mariah Carey - I'll Be There (Video)-UIt3dx4an9c.mp3
# [youtube] 0IA3ZvCkRkQ: Downloading webpage
# [download] Destination: Mariah Carey - Hero (Official HD Video)-0IA3ZvCkRkQ.webm
# [download] 100% of 1.57MiB in 00:03
# [ffmpeg] Destination: Mariah Carey - Hero (Official HD Video)-0IA3ZvCkRkQ.mp3
# Deleting original file Mariah Carey - Hero (Official HD Video)-0IA3ZvCkRkQ.webm (pass -k to keep)
# Mariah Carey - Hero (Official HD Video)-0IA3ZvCkRkQ.mp3
# [youtube] qq09UkPRdFY: Downloading webpage
# [download] Destination: Mariah Carey - Fantasy (Official HD Video)-qq09UkPRdFY.webm
# [download] 100% of 1.53MiB in 00:03
# [ffmpeg] Destination: Mariah Carey - Fantasy (Official HD Video)-qq09UkPRdFY.mp3
# Deleting original file Mariah Carey - Fantasy (Official HD Video)-qq09UkPRdFY.webm (pass -k to keep)
# Mariah Carey - Fantasy (Official HD Video)-qq09UkPRdFY.mp3
# [youtube] LfRNRymrv9k: Downloading webpage
# [download] Destination: Mariah Carey - Always Be My Baby (Official Music Video)-LfRNRymrv9k.webm
# [download] 100% of 1.57MiB in 00:02
# [ffmpeg] Destination: Mariah Carey - Always Be My Baby (Official Music Video)-LfRNRymrv9k.mp3
# Deleting original file Mariah Carey - Always Be My Baby (Official Music Video)-LfRNRymrv9k.webm (pass -k to keep)
# Mariah Carey - Always Be My Baby (Official Music Video)-LfRNRymrv9k.mp3
# [youtube] mIhI23gBBPQ: Downloading webpage
# [download] Destination: Mariah Carey - My All (Official HD Video)-mIhI23gBBPQ.webm
# [download] 100% of 1.52MiB in 00:02
# [ffmpeg] Destination: Mariah Carey - My All (Official HD Video)-mIhI23gBBPQ.mp3
# Deleting original file Mariah Carey - My All (Official HD Video)-mIhI23gBBPQ.webm (pass -k to keep)
# Mariah Carey - My All (Official HD Video)-mIhI23gBBPQ.mp3
# [youtube] OAZG2duVte4: Downloading webpage
# [download] Destination: Mariah Carey - I Still Believe (Official Video)-OAZG2duVte4.webm
# [download] 100% of 1.48MiB in 00:02
# [ffmpeg] Destination: Mariah Carey - I Still Believe (Official Video)-OAZG2duVte4.mp3
# Deleting original file Mariah Carey - I Still Believe (Official Video)-OAZG2duVte4.webm (pass -k to keep)
# Mariah Carey - I Still Believe (Official Video)-OAZG2duVte4.mp3
# [youtube] jtoC6RXwaVc: Downloading webpage
# [download] Destination: PLANET FUNK - The Switch (Official Video)-jtoC6RXwaVc.webm
# [download] 100% of 1.46MiB in 00:06
# [ffmpeg] Destination: PLANET FUNK - The Switch (Official Video)-jtoC6RXwaVc.mp3
# Deleting original file PLANET FUNK - The Switch (Official Video)-jtoC6RXwaVc.webm (pass -k to keep)
# PLANET FUNK - The Switch (Official Video)-jtoC6RXwaVc.mp3
# [youtube] WsW8wiWDa0A: Downloading webpage
# [download] Destination: Brian McFadden - Irish Son-WsW8wiWDa0A.webm
# [download] 100% of 1.59MiB in 00:05
# [ffmpeg] Destination: Brian McFadden - Irish Son-WsW8wiWDa0A.mp3
# Deleting original file Brian McFadden - Irish Son-WsW8wiWDa0A.webm (pass -k to keep)
# Brian McFadden - Irish Son-WsW8wiWDa0A.mp3
# [youtube] okO6PPa6qRA: Downloading webpage
# [download] Destination: Brian McFadden - Be True To Your Women-okO6PPa6qRA.webm
# [download] 100% of 1.43MiB in 00:06
# [ffmpeg] Destination: Brian McFadden - Be True To Your Women-okO6PPa6qRA.mp3
# Deleting original file Brian McFadden - Be True To Your Women-okO6PPa6qRA.webm (pass -k to keep)
# Brian McFadden - Be True To Your Women-okO6PPa6qRA.mp3
# [youtube] V08MYfk0mcI: Downloading webpage
# [download] Destination: Brian McFadden - Sorry Love Daddy-V08MYfk0mcI.m4a
# [download] 100% of 4.68MiB in 00:09
# [ffmpeg] Destination: Brian McFadden - Sorry Love Daddy-V08MYfk0mcI.mp3
# Deleting original file Brian McFadden - Sorry Love Daddy-V08MYfk0mcI.m4a (pass -k to keep)
# Brian McFadden - Sorry Love Daddy-V08MYfk0mcI.mp3
# [youtube] iTM-DFdtg78: Downloading webpage
# [download] Destination: Brian McFadden - Demons-iTM-DFdtg78.webm
# [download] 100% of 1.47MiB in 00:05
# [ffmpeg] Destination: Brian McFadden - Demons-iTM-DFdtg78.mp3
# Deleting original file Brian McFadden - Demons-iTM-DFdtg78.webm (pass -k to keep)
# Brian McFadden - Demons-iTM-DFdtg78.mp3
# [youtube] H64QG4UsrGI: Downloading webpage
# [download] Destination: Mario - Let Me Love You (Official Video)-H64QG4UsrGI.webm
# [download] 100% of 1.62MiB in 00:02
# [ffmpeg] Destination: Mario - Let Me Love You (Official Video)-H64QG4UsrGI.mp3
# Deleting original file Mario - Let Me Love You (Official Video)-H64QG4UsrGI.webm (pass -k to keep)
# Mario - Let Me Love You (Official Video)-H64QG4UsrGI.mp3
# [youtube] cCYGyg1H56s: Downloading webpage
# [download] Destination: Artie Shaw  - Beguin The Beguine ( Cole Porter )-cCYGyg1H56s.webm
# [download] 100% of 1.25MiB in 00:03
# [ffmpeg] Destination: Artie Shaw  - Beguin The Beguine ( Cole Porter )-cCYGyg1H56s.mp3
# Deleting original file Artie Shaw  - Beguin The Beguine ( Cole Porter )-cCYGyg1H56s.webm (pass -k to keep)
# Artie Shaw  - Beguin The Beguine ( Cole Porter )-cCYGyg1H56s.mp3
# [youtube] q_c2sUArjQk: Downloading webpage
# [download] Destination: The Zutons - Confusion-q_c2sUArjQk.webm
# [download] 100% of 1.47MiB in 00:05
# [ffmpeg] Destination: The Zutons - Confusion-q_c2sUArjQk.mp3
# Deleting original file The Zutons - Confusion-q_c2sUArjQk.webm (pass -k to keep)
# The Zutons - Confusion-q_c2sUArjQk.mp3
# [youtube] LE82k3OqkvM: Downloading webpage
# [download] Destination: Mobb Deep - Win or Lose-LE82k3OqkvM.webm
# [download] 100% of 1.12MiB in 00:04
# [ffmpeg] Destination: Mobb Deep - Win or Lose-LE82k3OqkvM.mp3
# Deleting original file Mobb Deep - Win or Lose-LE82k3OqkvM.webm (pass -k to keep)
# Mobb Deep - Win or Lose-LE82k3OqkvM.mp3
# [youtube] VHDWunpDFeA: Downloading webpage
# [download] Destination: Stay With You by John Legend-VHDWunpDFeA.webm
# [download] 100% of 1.39MiB in 00:06
# [ffmpeg] Destination: Stay With You by John Legend-VHDWunpDFeA.mp3
# Deleting original file Stay With You by John Legend-VHDWunpDFeA.webm (pass -k to keep)
# Stay With You by John Legend-VHDWunpDFeA.mp3
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ProtocolError: ('Connection aborted.', OSError(0, 'Error'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-22-c4f7180958ee> in <module>
#       1 for i in range(len(ids)):
# ----> 2     create_spectrogram(ids.iloc[i], artists.iloc[i], tracks.iloc[i])
#
# ~\PycharmProjects\MERA\audio\audio_service.py in create_spectrogram(id, track, artist)
#      31
#      32     search_name = track + " by " + artist
# ---> 33     res = YoutubeSearch(search_name, max_results=1).to_dict()
#      34     link = "https://www.youtube.com" + res[0]["url_suffix"]
#      35
#
# ~\anaconda3\lib\site-packages\youtube_search\__init__.py in __init__(self, search_terms, max_results)
#       8         self.search_terms = search_terms
#       9         self.max_results = max_results
# ---> 10         self.videos = self._search()
#      11
#      12     def _search(self):
#
# ~\anaconda3\lib\site-packages\youtube_search\__init__.py in _search(self)
#      14         BASE_URL = "https://youtube.com"
#      15         url = f"{BASE_URL}/results?search_query={encoded_search}"
# ---> 16         response = requests.get(url).text
#      17         while "ytInitialData" not in response:
#      18             response = requests.get(url).text
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError(0, 'Error'))
