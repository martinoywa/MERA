# %%
from audio_service import create_spectrogram

import pandas as pd

# %%
data = pd.read_csv("../data/train_with_lyrics.csv")
data.head()
# Out:
#    dzr_sng_id          MSD_sng_id        MSD_track_id   valence   arousal  \
# 0      213754  SORORTY12A67ADD67E  TRJIEJX12903CF2202 -0.682725  0.316758
# 1      216752  SOVJXGK12A8AE4760C  TRLBHVY128F4242C31 -1.400403  1.538229
# 2      239138  SOACXLC12AB018218D  TRQJZHB128F92FA42D -1.935250 -0.655810
# 3      254391  SOUTMGD12A8AE47448  TRCXLKK128F42366BF  0.815393  0.662457
# 4      266313  SOTITAA12A6D4F8DA4  TRPMWQM128F932C0C8  1.257460  1.086515
#
#          artist_name               track_name  \
# 0  Dark Tranquillity     Insanity's Crescendo
# 1   Anorexia Nervosa    Stabat mater dolorosa
# 2  Jimmy Witherspoon  Ain't Nobody's Business
# 3    Uniting Nations             Out Of Touch
# 4        The Walkmen         Brandy alexander
#
#                                               Lyrics
# 0  Gently hold our hands\r\nGently hold our heads...
# 1  We are the Sun\r\nWe are the dead stars\r\nWe ...
# 2                                                NaN
# ...

# %%
data = data.dropna()
data.head()
# Out:
#    dzr_sng_id          MSD_sng_id        MSD_track_id   valence   arousal  \
# 0      213754  SORORTY12A67ADD67E  TRJIEJX12903CF2202 -0.682725  0.316758
# 1      216752  SOVJXGK12A8AE4760C  TRLBHVY128F4242C31 -1.400403  1.538229
# 3      254391  SOUTMGD12A8AE47448  TRCXLKK128F42366BF  0.815393  0.662457
# 4      266313  SOTITAA12A6D4F8DA4  TRPMWQM128F932C0C8  1.257460  1.086515
# 5      283306  SOCSRIF12AB018E4FC  TRABHPA12903CEC222  0.373325 -0.923151
#
#          artist_name             track_name  \
# 0  Dark Tranquillity   Insanity's Crescendo
# 1   Anorexia Nervosa  Stabat mater dolorosa
# 3    Uniting Nations           Out Of Touch
# 4        The Walkmen       Brandy alexander
# 5     Duke Ellington                Caravan
#
#                                               Lyrics
# 0  Gently hold our hands\r\nGently hold our heads...
# 1  We are the Sun\r\nWe are the dead stars\r\nWe ...
# 3  You're out of touch\r\nI'm out of time\r\nBut ...
# ...

# %%
ids = data["dzr_sng_id"][100:]
artists = data["artist_name"][100:]
tracks = data["track_name"][100:]

# %%
for i in range(len(ids)):
    create_spectrogram(ids.iloc[i], artists.iloc[i], tracks.iloc[i])
# Out:
# [youtube] FK1oPj6zJmU: Downloading webpage
# [download] Destination: Anti-Flag Exodus_Emigre (Lyrics)-FK1oPj6zJmU.webm
# [download] 100% of 1.02MiB in 00:02
# [ffmpeg] Destination: Anti-Flag Exodus_Emigre (Lyrics)-FK1oPj6zJmU.mp3
# Deleting original file Anti-Flag Exodus_Emigre (Lyrics)-FK1oPj6zJmU.webm (pass -k to keep)
# Anti-Flag Exodus_Emigre (Lyrics)-FK1oPj6zJmU.mp3
# C:\Users\marti\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7558: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
# [youtube] rRaBJplKJxQ: Downloading webpage
# [download] Destination: Anti-Flag State Funeral (Lyrics)-rRaBJplKJxQ.webm
# [download] 100% of 692.72KiB in 00:05
# [ffmpeg] Destination: Anti-Flag State Funeral (Lyrics)-rRaBJplKJxQ.mp3
# Deleting original file Anti-Flag State Funeral (Lyrics)-rRaBJplKJxQ.webm (pass -k to keep)
# Anti-Flag State Funeral (Lyrics)-rRaBJplKJxQ.mp3
# [youtube] 80X9Lf-fuOc: Downloading webpage
# ...
