# %%
import pandas as pd
import numpy as np
import os

# %%
path = "../audio/spectrograms/"

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    dzr_sng_id   valence   arousal        artist_name             track_name  \
# 0      213754 -0.682725  0.316758  Dark Tranquillity   Insanity's Crescendo
# 1      216752 -1.400403  1.538229   Anorexia Nervosa  Stabat mater dolorosa
# 2      254391  0.815393  0.662457    Uniting Nations           Out Of Touch
# 3      266313  1.257460  1.086515        The Walkmen       Brandy alexander
# 4      283306  0.373325 -0.923151     Duke Ellington                Caravan
#
#                                               Lyrics
# 0  Gently hold our hands\nGently hold our heads o...
# 1  We are the Sun\nWe are the dead stars\nWe are ...
# 2  You're out of touch\nI'm out of time\nBut I'm ...
# 3  You finally close the door\nYou've left open w...
# 4  随分先に行ってしまった 光の下のキャラバン\nトンネルに残響 塞いだ耳 自分嫌いな自分が好き...

# %%
data.shape
# Out:
# (10515, 6)

# %%
# get the names of all songs that have been downloaded
# load data for only those songs
songs = os.listdir(path)
songs = [np.int64(_[:-4]) for _ in songs]

# %%
data = data[data["dzr_sng_id"].isin(songs)]
data.head()
# Out:
#    dzr_sng_id   valence   arousal        artist_name             track_name  \
# 0      213754 -0.682725  0.316758  Dark Tranquillity   Insanity's Crescendo
# 1      216752 -1.400403  1.538229   Anorexia Nervosa  Stabat mater dolorosa
# 2      254391  0.815393  0.662457    Uniting Nations           Out Of Touch
# 3      266313  1.257460  1.086515        The Walkmen       Brandy alexander
# 4      283306  0.373325 -0.923151     Duke Ellington                Caravan
#
#                                               Lyrics
# 0  Gently hold our hands\nGently hold our heads o...
# 1  We are the Sun\nWe are the dead stars\nWe are ...
# 2  You're out of touch\nI'm out of time\nBut I'm ...
# 3  You finally close the door\nYou've left open w...
# 4  随分先に行ってしまった 光の下のキャラバン\nトンネルに残響 塞いだ耳 自分嫌いな自分が好き...

# %%
data
# Out:
#      dzr_sng_id   valence   arousal                   artist_name  \
# 0        213754 -0.682725  0.316758             Dark Tranquillity
# 1        216752 -1.400403  1.538229              Anorexia Nervosa
# 2        254391  0.815393  0.662457               Uniting Nations
# 3        266313  1.257460  1.086515                   The Walkmen
# 4        283306  0.373325 -0.923151                Duke Ellington
# ..          ...       ...       ...                           ...
# 333      597166  0.722613 -0.038160                         Mario
# 334      597189  0.815393  0.662457  Artie Shaw and his orchestra
# 335      597801  0.526139 -1.628377                    The Zutons
# 336      597899  0.373325 -0.923151                     Mobb Deep
# 337      598057  1.071901  0.846830                   John Legend
#
#                 track_name                                             Lyrics
# 0     Insanity's Crescendo  Gently hold our hands\nGently hold our heads o...
# ...

# %%
# add the path
PATH = []
for i in range(data.shape[0]):
    image_path = os.path.join(path, str(data['dzr_sng_id'][i]) + '.png')
    PATH.append(image_path)

# %%
data["Path"] = PATH

# %%
data.head()
# Out:
#    dzr_sng_id   valence   arousal        artist_name             track_name  \
# 0      213754 -0.682725  0.316758  Dark Tranquillity   Insanity's Crescendo
# 1      216752 -1.400403  1.538229   Anorexia Nervosa  Stabat mater dolorosa
# 2      254391  0.815393  0.662457    Uniting Nations           Out Of Touch
# 3      266313  1.257460  1.086515        The Walkmen       Brandy alexander
# 4      283306  0.373325 -0.923151     Duke Ellington                Caravan
#
#                                               Lyrics  \
# 0  Gently hold our hands\nGently hold our heads o...
# 1  We are the Sun\nWe are the dead stars\nWe are ...
# 2  You're out of touch\nI'm out of time\nBut I'm ...
# 3  You finally close the door\nYou've left open w...
# 4  随分先に行ってしまった 光の下のキャラバン\nトンネルに残響 塞いだ耳 自分嫌いな自分が好き...
#
#                                Path
# 0  ../audio/spectrograms/213754.png
# 1  ../audio/spectrograms/216752.png
# 2  ../audio/spectrograms/254391.png
# 3  ../audio/spectrograms/266313.png
# ...

# %%
data.drop("dzr_sng_id", axis=1, inplace=True)

# %%
data.to_csv("mvp_data.csv", index=False)
